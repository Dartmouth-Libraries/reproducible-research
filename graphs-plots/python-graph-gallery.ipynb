# %%
# library & dataset
import seaborn as sns
df = sns.load_dataset('iris')

# Plot the histogram thanks to the displot function
# this uses the kde - KDE represents the data using a continuous probability density curve 
sns.displot( data=df["sepal_length"], kde=True )
# current kernel: python 3.12

# %%
# bin number 
# libraries & dataset
import seaborn as sns
import matplotlib.pyplot as plt
  
sns.set_theme(style="darkgrid")
df = sns.load_dataset("iris")

sns.histplot(data=df, x="sepal_length", bins=20)
plt.show()

# %%
# libraries & dataset
import seaborn as sns
import matplotlib.pyplot as plt
  
sns.set_theme(style="darkgrid")
df = sns.load_dataset("iris")

sns.histplot(data=df, x="sepal_length", bins=9)
plt.show()

# %%
# library & dataset
# boxplot to compare species sepal_length 
import seaborn as sns
df = sns.load_dataset('iris')

sns.boxplot( x=df["species"], y=df["sepal_length"] )
# Out:
# <Axes: xlabel='species', ylabel='sepal_length'>

# %%
#pip install pypalettes

# %%
# libraries & dataset
import seaborn as sns
import matplotlib.pyplot as plt
from pypalettes import load_palette

sns.set_theme(style="darkgrid")
df = sns.load_dataset("iris")
palette = load_palette("Acadia", keep_first_n=3)

sns.boxplot(hue=df["species"], y=df["sepal_length"], palette=palette)
plt.show()

# %%
# library & dataset
import seaborn as sns
df = sns.load_dataset('iris')

# Make default density plot
sns.kdeplot(df['sepal_width'])
# Out:
# <Axes: xlabel='sepal_width', ylabel='Density'>

# %%
import matplotlib.pyplot as plt
import seaborn as sns

df = sns.load_dataset('iris')

sns.set_theme(style="darkgrid")
sns.kdeplot(df['sepal_width'], fill=True, color="r")
sns.kdeplot(df['sepal_length'], fill=True, color="b")
plt.show()

# %%
pip install plotnine.data
# Out:
# /opt/anaconda3/lib/python3.12/pty.py:95: DeprecationWarning: This process (pid=26425) is multi-threaded, use of forkpty() may lead to deadlocks in the child.
#   pid, fd = os.forkpty()
# ERROR: Could not find a version that satisfies the requirement plotnine.data (from versions: none)
# ERROR: No matching distribution found for plotnine.data
# Note: you may need to restart the kernel to use updated packages.

# %%
# ----- diamond prices by cut (Seaborn + Matplotlib)

import seaborn as sns
import matplotlib.pyplot as plt

# -----  Load the built‑in "diamonds" dataset
# NOTE: This requires an internet connection the first time it runs.
#       Seaborn caches the CSV locally, so subsequent runs are fast.
diamond_data = sns.load_dataset('diamonds')   # ← straight quotes!

# --- Global figure/plot style settings
plt.rcParams["figure.figsize"] = (12, 8)       # explicit tuple
sns.set_theme(style="whitegrid")              # modern seaborn theme

# kde plot 
# `cut=0` tells seaborn **not** to extend the curve beyond the data.
# `hue='cut'` colours each cut category separately.
sns.kdeplot(
    data=diamond_data,
    x="price",
    hue="cut",          # column that defines the groups
    cut=0,              # KDE extension parameter (not the column)
    fill=True,          # shade under the curves (needs seaborn ≥0.11)
    common_norm=False,  # each hue gets its own normalisation
    alpha=1.0,          # fully opaque fill
    linewidth=1.5,      # make the lines a bit thicker
)

#add to the figure and show
plt.title("Distribution of Diamond Prices by Cut")
plt.xlabel("Price (US $)")
plt.ylabel("Density")
plt.legend(title="Cut", loc="upper right")   # optional, but clearer
plt.tight_layout()
plt.show()
# Out:
# /var/folders/sg/cy13dc_j0vzg_r3xrvskyw500000gq/T/ipykernel_26425/4036951283.py:43: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend(title="Cut", loc="upper right")   # optional, but clearer
# /var/folders/sg/cy13dc_j0vzg_r3xrvskyw500000gq/T/ipykernel_26425/4036951283.py:44: UserWarning: Glyph 8239 (\N{NARROW NO-BREAK SPACE}) missing from font(s) Arial.
#   plt.tight_layout()
# /opt/anaconda3/lib/python3.12/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 8239 (\N{NARROW NO-BREAK SPACE}) missing from font(s) Arial.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/anaconda3/lib/python3.12/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 8239 (\N{NARROW NO-BREAK SPACE}) missing from font(s) Arial.
#   fig.canvas.print_figure(bytes_io, **kw)
