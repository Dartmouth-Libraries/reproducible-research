# %%
import pandas as pd 
from pathlib import Path
import collections
import seaborn as sns
import matplotlib.pyplot as plt

# %%
inputdir = Path("../data/resilience/merged")
data = pd.read_csv(Path(inputdir, "merged_wos_files.csv"), encoding = 'utf-8', index_col=[0])
data.head()
# Out:
#   PT                                                 AU   BA   BE   GP  \
# 0  J              Jiang, YW; Ritchie, BW; Verreynne, ML  NaN  NaN  NaN
# 1  J  Nystrom, M; Graham, NAJ; Lokrantz, J; Norstrom...  NaN  NaN  NaN
# 2  J                                         Cassidy, S  NaN  NaN  NaN
# 3  J                              Adeyeye, K; Emmitt, S  NaN  NaN  NaN
# 4  J  Wiig, S; Haraldseid-Driftland, C; Dombestein, ...  NaN  NaN  NaN
#
#                                                   AF   BF   CA  \
# 0  Jiang, Yawei; Ritchie, Brent W.; Verreynne, Ma...  NaN  NaN
# 1  Nystrom, M.; Graham, N. A. J.; Lokrantz, J.; N...  NaN  NaN
# 2                                     Cassidy, Simon  NaN  NaN
# 3                     Adeyeye, Kemi; Emmitt, Stephen  NaN  NaN
# 4  Wiig, Siri; Haraldseid-Driftland, Cecilie; Dom...  NaN  NaN
#
#                                                   TI  \
# 0  Developing disaster resilience: A processual a...
# ...

# %%
data.loc[:, "DE"] = data.loc[:, "DE"].fillna("")

# %%
data.DE.tolist()
# Out:
# ['Disaster resilience; Dynamic capabilities; Resilience process; Trial-and-error reflection; Turbulent environments; Crisis; Disaster; Tourism organisations',
#  'Diversity; Functional groups; Management; Phase shifts; Coral reefs; Resilience',
#  'resilience; academic resilience; adversity; measuring resilience; student health and wellbeing; student retention; self-efficacy; self-regulated learning',
#  'Governance; Integration; Flooding; Resilience; Architecture; Planning',
#  'Resilience in healthcare; Researching researchers; Insider research; Methodological challenges and strategies; Research ethics',
#  'assets; hidden resilience; protective resources; resilience; street youth',
#  'adaptation; circularity; research agenda; resilience; resource loops; transformation',
#  'regionalism; metaphors; resilience',
#  'resilience; developmental psychopathology; prevention; buffer',
#  'resilience; digital inclusion; rural broadband; ICTs',
# ...

# %%
#keyword summaries
kwslist = data.loc[:, "DE"].tolist()    #Author Keywords
#kwslist = data.loc[:, "ID"].tolist()     #Keywords Plus

kwslist2 = [kws.split(";") for kws in kwslist]
kwslist3 = [[kw.strip() for kw in kws] for kws in kwslist2]
kwslist4 = [kw.strip().lower() for kws in kwslist3 for kw in kws if kw != ""]
kwsfreqs = collections.Counter(kwslist4)
kwsfreqs
# Out:
# Counter({'resilience': 1901,
#          'community resilience': 131,
#          'urban resilience': 104,
#          'vulnerability': 100,
#          'organizational resilience': 90,
#          'adaptation': 85,
#          'disaster resilience': 78,
#          'stress': 76,
#          'climate change': 74,
#          'sustainability': 69,
#          'recovery': 68,
#          'resilience assessment': 63,
#          'psychological resilience': 55,
#          'risk': 53,
#          'disaster': 50,
#          'critical infrastructure': 50,
#          'mental health': 48,
#          'coping': 47,
#          'trauma': 44,
#          'community': 44,
#          'social-ecological systems': 42,
#          'adaptive capacity': 40,
#          'disasters': 38,
#          'covid-19': 38,
#          'indicators': 37,
#          'reliability': 37,
#          'depression': 37,
#          'social resilience': 35,
#          'governance': 34,
#          'measurement': 34,
# ...
